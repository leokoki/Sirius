# %% [markdown]
# # Análise Fatorial Exploratória
#
# Nesta atividade iremos trabalho com um conjunto de dados od [ifood](https://www.kaggle.com/datasets/jackdaoud/marketing-data). Este conjunto sofreu um pre tratamento para podermos focar mais na análise fatorial.

# %% [markdown]
# ## Atividade 1: Importe os dados e verifique se há dados faltantes. Se houver dados faltantes, faça os tratamentos adequados.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
from factor_analyzer.factor_analyzer import calculate_kmo
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/content/ifood2 - base.xlsx')
pd.set_option('display.max_columns', None)

# %%
df.head(2)
# Out:
#      ID  ano_nascimento nivel_educacao estado_civil  renda_mensal  \
# 0  6862            1971       graduado   divorciado        650.38
# 1  5376            1979       graduado       casado        919.92
#
#    num_filhos_pequenos  num_filhos_adolescentes  num_dias_primeira_compra  \
# 0                    0                        0                        42
# 1                    1                        0                       539
#
#    num_dias_ultima_compra  gasto_vinho_ult_2anos  gasto_prod_frutas_ult_2anos  \
# 0                      65                      1                            1
# 1                      42                      1                            1
#
#    gasto_prod_carne_ult_2anos  gasto_prod_peixe_ult_2anos  \
# 0                           3                           1
# 1                        1725                           1
#
#    gasto_prod_doces_ulti_2anos  qtde_compras_desconto  \
# 0                            1                     15
# 1                            1                     15
#
#    qtde_compras_web_restaurante  qtde_compras_catalogo  qtde_compras_loja  \
# 0                             0                      0                  0
# 1                             0                     28                  0
#
#    qtde_vistas_web_ult_mes  aceitou_qtde_oferta  reclamou_ult_2anos
# 0                       20                    0                   0
# 1                        1                    0                   0

# %%
df.shape
# Out:
# (2236, 21)

# %%
df.describe().T
# Out:
#                                count          mean          std      min  \
# ID                            2236.0   5591.551878  3245.240106     0.00
# ano_nascimento                2236.0   1968.796512    11.980604  1893.00
# renda_mensal                  2236.0  19632.809070  9442.935676   650.38
# num_filhos_pequenos           2236.0      0.444991     0.538551     0.00
# num_filhos_adolescentes       2236.0      0.506261     0.544615     0.00
# num_dias_primeira_compra      2236.0    353.335868   202.064179     0.00
# num_dias_ultima_compra        2236.0     49.147138    28.954880     0.00
# gasto_vinho_ult_2anos         2236.0    303.873435   336.876776     0.00
# gasto_prod_frutas_ult_2anos   2236.0     26.271020    39.761356     0.00
# gasto_prod_carne_ult_2anos    2236.0    166.924419   225.778550     0.00
# gasto_prod_peixe_ult_2anos    2236.0     37.405188    54.436749     0.00
# gasto_prod_doces_ulti_2anos   2236.0     27.081395    41.300943     0.00
# qtde_compras_desconto         2236.0      2.322898     1.932052     0.00
# qtde_compras_web_restaurante  2236.0      4.082737     2.779736     0.00
# qtde_compras_catalogo         2236.0      2.659213     2.920752     0.00
# qtde_compras_loja             2236.0      5.789356     3.253756     0.00
# qtde_vistas_web_ult_mes       2236.0      5.317531     2.424756     0.00
# aceitou_qtde_oferta           2236.0      0.445886     0.889524     0.00
# reclamou_ult_2anos            2236.0      0.009392     0.096477     0.00
#
#                                    25%       50%       75%        max
# ID                             2828.25   5458.50   8427.75   11191.00
# ano_nascimento                 1959.00   1970.00   1977.00    1996.00
# renda_mensal                  13245.68  19286.09  25739.94  250626.32
# num_filhos_pequenos               0.00      0.00      1.00       2.00
# num_filhos_adolescentes           0.00      0.00      1.00       2.00
# num_dias_primeira_compra        180.75    355.00    528.00     699.00
# num_dias_ultima_compra           24.00     49.00     74.00      99.00
# gasto_vinho_ult_2anos            23.00    173.00    505.00    1493.00
# gasto_prod_frutas_ult_2anos       1.00      8.00     33.00     199.00
# gasto_prod_carne_ult_2anos       16.00     67.00    232.00    1725.00
# gasto_prod_peixe_ult_2anos        3.00     12.00     50.00     259.00
# gasto_prod_doces_ulti_2anos       1.00      8.00     33.00     263.00
# qtde_compras_desconto             1.00      2.00      3.00      15.00
# qtde_compras_web_restaurante      2.00      4.00      6.00      27.00
# qtde_compras_catalogo             0.00      2.00      4.00      28.00
# qtde_compras_loja                 3.00      5.00      8.00      13.00
# qtde_vistas_web_ult_mes           3.00      6.00      7.00      20.00
# aceitou_qtde_oferta               0.00      0.00      1.00       5.00
# reclamou_ult_2anos                0.00      0.00      0.00       1.00

# %%
df.isnull().sum()
# Out:
# ID                              0
# ano_nascimento                  0
# nivel_educacao                  0
# estado_civil                    0
# renda_mensal                    0
# num_filhos_pequenos             0
# num_filhos_adolescentes         0
# num_dias_primeira_compra        0
# num_dias_ultima_compra          0
# gasto_vinho_ult_2anos           0
# gasto_prod_frutas_ult_2anos     0
# gasto_prod_carne_ult_2anos      0
# gasto_prod_peixe_ult_2anos      0
# gasto_prod_doces_ulti_2anos     0
# qtde_compras_desconto           0
# qtde_compras_web_restaurante    0
# qtde_compras_catalogo           0
# qtde_compras_loja               0
# qtde_vistas_web_ult_mes         0
# aceitou_qtde_oferta             0
# reclamou_ult_2anos              0
# dtype: int64

# %% [markdown]
# ## Atividade 2: Faça uma preparação dos dados, isto é, elimine colunas irrelevantes e transforme colunas categóricas ordinais.

# %%
df.drop(columns=['ID','estado_civil','reclamou_ult_2anos'], inplace= True )

# %%
# seu código
nivel_educacao = {
    'graduado':2
    , 'doutorado':5
    , 'mestrado':4
    , 'ensino_medio':1
    , 'pos':3
}
df.nivel_educacao = df.nivel_educacao.map(nivel_educacao)

# %%
df.head()
# Out:
#    ano_nascimento  nivel_educacao  renda_mensal  num_filhos_pequenos  \
# 0            1971               2        650.38                    0
# 1            1979               2        919.92                    1
# 2            1973               2       1316.54                    1
# 3            1963               5       1512.41                    1
# 4            1969               2       1664.66                    0
#
#    num_filhos_adolescentes  num_dias_primeira_compra  num_dias_ultima_compra  \
# 0                        0                        42                      65
# 1                        0                       539                      42
# 2                        0                       442                      56
# 3                        1                         6                      29
# 4                        1                       267                       0
#
#    gasto_vinho_ult_2anos  gasto_prod_frutas_ult_2anos  \
# 0                      1                            1
# 1                      1                            1
# 2                      2                            1
# 3                      5                            0
# 4                     16                            4
#
#    gasto_prod_carne_ult_2anos  gasto_prod_peixe_ult_2anos  \
# 0                           3                           1
# 1                        1725                           1
# 2                           1                           0
# 3                           1                           1
# 4                          12                           2
#
#    gasto_prod_doces_ulti_2anos  qtde_compras_desconto  \
# 0                            1                     15
# 1                            1                     15
# 2                            0                      0
# 3                            1                     15
# 4                            4                      0
#
#    qtde_compras_web_restaurante  qtde_compras_catalogo  qtde_compras_loja  \
# 0                             0                      0                  0
# 1                             0                     28                  0
# 2                             0                      0                  0
# 3                             0                      0                  0
# 4                            25                      0                  0
#
#    qtde_vistas_web_ult_mes  aceitou_qtde_oferta
# 0                       20                    0
# 1                        1                    0
# 2                       14                    0
# 3                       19                    0
# 4                        1                    0

# %%
df.columns
# Out:
# Index(['ano_nascimento', 'nivel_educacao', 'renda_mensal',
#        'num_filhos_pequenos', 'num_filhos_adolescentes',
#        'num_dias_primeira_compra', 'num_dias_ultima_compra',
#        'gasto_vinho_ult_2anos', 'gasto_prod_frutas_ult_2anos',
#        'gasto_prod_carne_ult_2anos', 'gasto_prod_peixe_ult_2anos',
#        'gasto_prod_doces_ulti_2anos', 'qtde_compras_desconto',
#        'qtde_compras_web_restaurante', 'qtde_compras_catalogo',
#        'qtde_compras_loja', 'qtde_vistas_web_ult_mes', 'aceitou_qtde_oferta'],
#       dtype='object')

# %%
df['total_filhos'] = df['num_filhos_pequenos'] + df['num_filhos_adolescentes']
df['gasto_total'] = df[['gasto_vinho_ult_2anos', 'gasto_prod_frutas_ult_2anos',
       'gasto_prod_carne_ult_2anos', 'gasto_prod_peixe_ult_2anos',
       'gasto_prod_doces_ulti_2anos']].sum(axis=1)
df.head(3)
# Out:
#    ano_nascimento  nivel_educacao  renda_mensal  num_filhos_pequenos  \
# 0            1971               2        650.38                    0
# 1            1979               2        919.92                    1
# 2            1973               2       1316.54                    1
#
#    num_filhos_adolescentes  num_dias_primeira_compra  num_dias_ultima_compra  \
# 0                        0                        42                      65
# 1                        0                       539                      42
# 2                        0                       442                      56
#
#    gasto_vinho_ult_2anos  gasto_prod_frutas_ult_2anos  \
# 0                      1                            1
# 1                      1                            1
# 2                      2                            1
#
#    gasto_prod_carne_ult_2anos  gasto_prod_peixe_ult_2anos  \
# 0                           3                           1
# 1                        1725                           1
# 2                           1                           0
#
#    gasto_prod_doces_ulti_2anos  qtde_compras_desconto  \
# 0                            1                     15
# 1                            1                     15
# 2                            0                      0
#
#    qtde_compras_web_restaurante  qtde_compras_catalogo  qtde_compras_loja  \
# 0                             0                      0                  0
# 1                             0                     28                  0
# 2                             0                      0                  0
#
#    qtde_vistas_web_ult_mes  aceitou_qtde_oferta  total_filhos  gasto_total
# 0                       20                    0             0            7
# 1                        1                    0             1         1729
# 2                       14                    0             1            4

# %%
df.drop(columns=['gasto_vinho_ult_2anos', 'gasto_prod_frutas_ult_2anos',
       'gasto_prod_carne_ult_2anos', 'gasto_prod_peixe_ult_2anos',
       'gasto_prod_doces_ulti_2anos','num_filhos_pequenos', 'num_filhos_adolescentes'] , inplace=True)

# %%
df.head()
# Out:
#    ano_nascimento  nivel_educacao  renda_mensal  num_dias_primeira_compra  \
# 0            1971               2        650.38                        42
# 1            1979               2        919.92                       539
# 2            1973               2       1316.54                       442
# 3            1963               5       1512.41                         6
# 4            1969               2       1664.66                       267
#
#    num_dias_ultima_compra  qtde_compras_desconto  \
# 0                      65                     15
# 1                      42                     15
# 2                      56                      0
# 3                      29                     15
# 4                       0                      0
#
#    qtde_compras_web_restaurante  qtde_compras_catalogo  qtde_compras_loja  \
# 0                             0                      0                  0
# 1                             0                     28                  0
# 2                             0                      0                  0
# 3                             0                      0                  0
# 4                            25                      0                  0
#
#    qtde_vistas_web_ult_mes  aceitou_qtde_oferta  total_filhos  gasto_total
# 0                       20                    0             0            7
# 1                        1                    0             1         1729
# 2                       14                    0             1            4
# 3                       19                    0             2            8
# 4                        1                    0             1           38

# %% [markdown]
# ## Atividade 3: Coloque os dados numa mesma escala e faça um heatmap para observar a correlação.

# %%
# # Instanciando a função StandardScaler
scaler = StandardScaler()

# %%
# Criando uma cópia do Dataframe
df_scaled = df.copy()

# %%
# Aplicando a padronização
df_scaled[df_scaled.columns] = scaler.fit_transform(df_scaled)

# %%
df_scaled.head()
# Out:
#    ano_nascimento  nivel_educacao  renda_mensal  num_dias_primeira_compra  \
# 0        0.183962       -0.819614     -2.010675                 -1.541122
# 1        0.851858       -0.819614     -1.982125                  0.919043
# 2        0.350936       -0.819614     -1.940113                  0.438890
# 3       -0.483933        1.530950     -1.919366                 -1.719323
# 4        0.016989       -0.819614     -1.903240                 -0.427365
#
#    num_dias_ultima_compra  qtde_compras_desconto  \
# 0                0.547625               6.562937
# 1               -0.246892               6.562937
# 2                0.236727              -1.202564
# 3               -0.695967               6.562937
# 4               -1.697749              -1.202564
#
#    qtde_compras_web_restaurante  qtde_compras_catalogo  qtde_compras_loja  \
# 0                     -1.469078              -0.910659          -1.779682
# 1                     -1.469078               8.678058          -1.779682
# 2                     -1.469078              -0.910659          -1.779682
# 3                     -1.469078              -0.910659          -1.779682
# 4                      7.526593              -0.910659          -1.779682
#
#    qtde_vistas_web_ult_mes  aceitou_qtde_oferta  total_filhos  gasto_total
# 0                 6.056590            -0.501375     -1.265354    -0.961378
# 1                -1.781003            -0.501375      0.064844     2.023883
# 2                 3.581561            -0.501375      0.064844    -0.966579
# 3                 5.644085            -0.501375      1.395042    -0.959645
# 4                -1.781003            -0.501375      0.064844    -0.907636

# %% [markdown]
# ## Atividade 4: Há um grupo de variáveis que trazem informações muito parecidas e possuem correlação entre si. Transforme todas essas variáveis em uma única.

# %%
# Plotando o heatmap
sns.heatmap(df_scaled.corr(), vmin= -1, vmax= 1, annot= False);

# %%
# seu código

# %% [markdown]
# ## Atividade 5: Faça e teste de esfericidade de Bartlett e conclua se as variáveis estão correlacionadas.
#
# Para realizar esse teste em `Python` usaremos a função `calculate_bartlett_sphericity` do pacote `factor_analyzer`.
#
# **Atenção!** Este pacote não vem instalado por padrão! Para instalá-lo use o comando `!pip install factor_analyzer`.
#
# A função que desejamos está no pacote `factor_analyzer` dentro do módulo `factor_analyzer`.
#
# Para mais detalhes consulte a documentação do pacote [aqui](https://factor-analyzer.readthedocs.io/en/latest/index.html).
#
# Está função retornará para nós dois valores: a estatística qui quadrado do teste e o p-valor. Consideraremos um nível de significância de 5%.

# %%
# !pip install factor_analyzer

# %%
# Retorna um q_quadrado e um P_valor

chi_squared, p_valor = calculate_bartlett_sphericity(df_scaled)

p_valor

# Com esse valor de p_valor igual a zero(0) podemos rejeitar a hipotese nula
# Out:
# 0.0

# %% [markdown]
# ## Atividade 6: Obtenha a medida de Kaiser-Meyer-Olkin e conclua se a análise fatorial é indicada.
#
# Pequenos valores de KMO indicam que as correlações entre os pares de variáveis não podem ser explicadas por outras variáveis, indicando que a análise fatorial não é adequada.
# KMO sempre varia entre 0 e 1, quanto maior melhor. Resultados abaixo de 0.5 indicam que análise fatorial não é adequada.

# %%
# Retorna o calculate_kmo

kmo_all, kmo_model = calculate_kmo(df_scaled)

kmo_model
# Out:
# 0.7931727533499676

# %% [markdown]
# ## Atividade 7: Encontre o número adequado de fatores para este problema.
#
# Para isso vamos usar a função `FactorAnalyzer` e o método `get_eigenvalues()` aplicado ao um objeto da classe `FactorAnalyzer`, após este calcular valores dos dados.
#
# O método `get_eigenvalues()` retorna dois objetos, sendo que o primeiro são os autovalores.

# %%
# Instanciando a função FactorAnalyzer
fa = FactorAnalyzer(rotation= None)

# %%
# Descobrindo os altos valores padronizando os dados
fa.fit(df_scaled)

ev, v = fa.get_eigenvalues()
ev
# Out:
# array([4.08909657, 1.78009726, 1.2819758 , 1.06687003, 0.92121427,
#        0.81304619, 0.77880082, 0.62550624, 0.48325118, 0.41813485,
#        0.3116751 , 0.27315779, 0.15717392])

# %%
sns.lineplot(x= range(1, df_scaled.shape[1] + 1), y= ev)
plt.title('Scree plot')
plt.xlabel('Fatores')
plt.ylabel('Autovalores')
plt.grid();

# %% [markdown]
# ## Atividade 8: Calcule a variância explicada acumulada.
#
# Para isso vamos usar o método `get_factor_variance()` aplicado ao nosso objetivo usado na realizaação da análise fatorial.

# %%
# recriando o nosso " fa "

fa = FactorAnalyzer(n_factors= 4, rotation= None)
fa.fit(df_scaled)

colunas = []
for i in range(4):
  colunas.append('Fator ' + str(i))

variancia_fator = pd.DataFrame(fa.get_factor_variance(),
                               index=['variancia','variancia proporcional','variancia acumulada'],
                               columns= colunas)

variancia_fator
# Out:
#                          Fator 0   Fator 1   Fator 2   Fator 3
# variancia               3.781525  1.316587  0.714877  0.396334
# variancia proporcional  0.290887  0.101276  0.054991  0.030487
# variancia acumulada     0.290887  0.392162  0.447153  0.477640

# %% [markdown]
# ## Atividade 9: Rotacione os fatores.
#
# Como estamos trabalhando com fatores que influenciam cliente, é interessante não ter um número muito grande, por isso vamos usar 4 fatores na análise a seguir.
#
# Esse processo pode ser feito de forma simples ao passar para a função `FactorAnalyzer()` os parâmetros de interesse, que no nosso caso são `n_factors` e `rotation='varimax`.
#
# Após expor nosso objeto aos dados, vamos acessar o atributo `loadinds_` que possui as cargas fatoriais.

# %%
# Instaciando a FatorAnalyzer
fa = FactorAnalyzer(n_factors= 4, rotation= 'varimax')

fa.fit(df_scaled)
# Out:
# FactorAnalyzer(n_factors=4, rotation='varimax', rotation_kwargs={})

# %%
cargas_fat = pd.DataFrame(fa.loadings_,
             index= df_scaled.columns,
             columns= colunas)

cargas_fat
# Out:
#                                Fator 0   Fator 1   Fator 2   Fator 3
# ano_nascimento               -0.135358  0.012542 -0.295261  0.046650
# nivel_educacao                0.057714 -0.028327  0.210473  0.070125
# renda_mensal                  0.708958 -0.160137  0.242668  0.086095
# num_dias_primeira_compra      0.126711  0.465653 -0.143265  0.022697
# num_dias_ultima_compra        0.017658  0.004026 -0.007856 -0.120968
# qtde_compras_desconto        -0.059267  0.577120  0.358639 -0.129972
# qtde_compras_web_restaurante  0.546394  0.373755  0.150289  0.004031
# qtde_compras_catalogo         0.777116 -0.042316  0.063503  0.130087
# qtde_compras_loja             0.749018  0.097011  0.111635 -0.144335
# qtde_vistas_web_ult_mes      -0.599016  0.684711 -0.137072  0.117113
# aceitou_qtde_oferta           0.347678  0.021375 -0.015393  0.624173
# total_filhos                 -0.559462  0.270485  0.582752 -0.099957
# gasto_total                   0.923870  0.037392  0.019570  0.221154

# %%
sns.heatmap(cargas_fat, vmin= -1, vmax= 1, annot= True);

# %% [markdown]
# ## Atividade 10: Obtenha a relação de cada fator com as variáveis que ele está influenciando.
#
# Cargas fatoriais indicam quanto um fator explica uma variável. Esses valores variam de -1 a 1. Quanto mais próximo de -1 ou de 1, mais o fator explica a variável.
#
# Vamos estabelecer um valor de corte para poder entender quais fatores explicam quais variáveis. Vamos considerar que esse valor de corte será 0.5.

# %%
fatores = {}
for i in range(4):
  fatores['Fator ' + str(i)] = cargas_fat[abs(cargas_fat.iloc[:,i]) > 0.5].iloc[:,i].index.tolist()

fatores
# Out:
# {'Fator 0': ['renda_mensal',
#   'qtde_compras_web_restaurante',
#   'qtde_compras_catalogo',
#   'qtde_compras_loja',
#   'qtde_vistas_web_ult_mes',
#   'total_filhos',
#   'gasto_total'],
#  'Fator 1': ['qtde_compras_desconto', 'qtde_vistas_web_ult_mes'],
#  'Fator 2': ['total_filhos'],
#  'Fator 3': ['aceitou_qtde_oferta']}

# %% [markdown]
# ## Atividade 11: Encontre um nome que represente cada fator.

# %% [markdown]
# * Fator 0: "Perfil de Consumo"
# * Fator 1: "Engajamento em Ofertas"
# * Fator 2: "Responsabilidade Familiar"
# * Fator 3: "Aceitação de Ofertas"
