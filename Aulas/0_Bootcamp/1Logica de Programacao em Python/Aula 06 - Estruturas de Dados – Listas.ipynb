# %% [markdown]
# <div>
# <p ><img  align="right" src="https://res.cloudinary.com/crunchbase-production/image/upload/c_lpad,h_256,w_256,f_auto,q_auto:eco,dpr_1/aj29iemt0ogdyrdlksd4" height="160px"></p>
# </div>
#
# <br>
# <br>
#
# # **Aula 06 - Estruturas de Dados – Listas**
#
# <br>
# <br>
#
# ___
#
# Uma lista (list) em Python, é uma coleção de valores, separados por vírgula e dentro de colchetes [].
#
# **Métodos da Lista**
# * **append(x)**: Adiciona um item ao fim da lista.
# * **extend(iterable)**: Prolonga a lista, adicionando no fim todos os elementos passado como parâmetro.
# * **insert(i, x)**: Insere um item em uma dada posição. O primeiro argumento é o índice do elemento antes do qual será feita a inserção.
# * **remove(x)**: Remove o primeiro item encontrado na lista cujo valor é igual a x.
# * **pop([i])**: Remove um item em uma dada posição na lista e o retorna. Se nenhum índice é especificado, a.pop() remove e devolve o último item da lista.
# * **clear()**: Remove todos os itens de uma lista.
# * **index(x)**: Devolve o índice do primeiro item cujo valor é igual a x.
# * **count(x)**: Devolve o número de vezes em que x aparece na lista.
# * **sort(*, key=None, reverse=False)**: Ordena os itens na lista (os argumentos podem ser usados para personalizar a ordenação.

# %% [markdown]
# **Criando uma Lista**

# %%
lista = []
#
print(type(lista))
# Out:
# <class 'list'>

# %%
lista = list()

print(lista)
# Out:
# []

# %%
lista = ['Sirius', 'Bootcamp', 2022, 205.5]

print(lista)
# Out:
# ['Sirius', 'Bootcamp', 2022, 205.5]

# %%
print(len(lista))
# Out:
# 4

# %% [markdown]
# **Acessando Elementos da Lista**

# %%
         # 0       1         2      3
         #  -4         -3    -2      -1
frutas = ['Maça', 'Banana', 'Uva', 'Abacaxi']

# %%
print(frutas[1])
# Out:
# Banana

# %%
print(frutas[-1])
# Out:
# Abacaxi

# %%
print(frutas[3])
# Out:
# Abacaxi

# %%
print(len(frutas))
# Out:
# 4

# %%
print(frutas[len(frutas)-1])
# Out:
# Abacaxi

# %%
frutas[2] = 'Melão'

print(frutas)
# Out:
# ['Maça', 'Banana', 'Melão', 'Abacaxi']

# %% [markdown]
# **Fatiando Listas**

# %%
# lista[inicio:fim:passo]

# %%
lista = [2,1,3,5,6,9,8,7, 'Sirius', 'Bootcamp']

# %%
print(lista[2:6])
# Out:
# [3, 5, 6, 9]

# %%
print(lista[1:5])
# Out:
# [1, 3, 5, 6]

# %%
print(lista[:5])
# Out:
# [2, 1, 3, 5, 6]

# %%
print(lista[5:])
# Out:
# [9, 8, 7, 'Sirius', 'Bootcamp']

# %% [markdown]
# **Métodos da Lista**

# %%
lista = [2, 1, 3, 5, 6, 5, 9 , 8, 7, 'Sirius', 'Bootcamp']

# %%
print(lista)
# Out:
# [2, 1, 3, 5, 6, 5, 9, 8, 7, 'Sirius', 'Bootcamp']

# %%
lista.append(11)

# %%
print(lista)
# Out:
# [2, 1, 3, 5, 6, 5, 9, 8, 7, 'Sirius', 'Bootcamp', 10, 11]

# %%
print(lista.index('Sirius'))
# Out:
# 9

# %%
lista.insert(1, 5)

print(lista)
# Out:
# [2, 5, 1, 3, 5, 6, 5, 9, 8, 7, 'Sirius', 'Bootcamp', 10, 11]

# %%
lista.pop()

print(lista)
# Out:
# [2, 5, 1, 3, 5, 6, 5, 9, 8, 7, 'Sirius', 'Bootcamp', 10]

# %%
lista.pop(2)

print(lista)
# Out:
# [2, 5, 3, 5, 6, 5, 9, 8, 7, 'Sirius', 'Bootcamp', 10]

# %%
lista.remove('Bootcamp')

print(lista)
# Out:
# [2, 5, 3, 5, 6, 5, 9, 8, 7, 10]

# %%
lista.sort() # Ordem crescente

print(lista)
# Out:
# [2, 3, 5, 5, 5, 6, 7, 8, 9, 10]

# %%
lista.sort(reverse=True) # Ordem descrecente

print(lista)
# Out:
# [10, 9, 8, 7, 6, 5, 5, 5, 3, 2]

# %%
print(lista.count(5))
# Out:
# 3

# %%
lista.extend([45,46,47])

print(lista)
# Out:
# [10, 9, 8, 7, 6, 5, 5, 5, 3, 2, 45, 46, 47]

# %%
lista.clear()

print(lista)
# Out:
# []

# %%
del lista

# %%
print(lista)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-232fa446ace9> in <module>
# ----> 1 print(lista)
#
# NameError: name 'lista' is not defined
